# %%
import pyodbc
import pandas as pd

# %%
cnxn_str = pyodbc.connect("Driver={SQL Server Native Client 11.0};"
            "Server=MSI\SQLEXPRESS;"
            "Database=FetchRewards;"
            "Trusted_Connection=yes;")

# %%
cursor=cnxn_str.cursor()

# %%
Receipt1= pd.read_sql('Select * from FetchRewards.dbo.Receipt1', cnxn_str)

# %%
Receipt1
# Out:
#                            _id  bonusPointsEarned  \
# 0     5ff1e1eb0a720f0523000575              500.0
# 1     5ff1e1bb0a720f052300056b              150.0
# 2     5ff1e1f10a720f052300057a                5.0
# 3     5ff1e1ee0a7214ada100056f                5.0
# 4     5ff1e1d20a7214ada1000561                5.0
# ...                        ...                ...
# 1114  603cc0630a720fde100003e6               25.0
# 1115  603d0b710a720fde1000042a                NaN
# 1116  603cf5290a720fde10000413                NaN
# 1117  603ce7100a7217c72c000405               25.0
# 1118  603c4fea0a7217c72c000389                NaN
#
#                                 bonusPointsEarnedReason pointsEarned  \
# 0     Receipt number 2 completed, bonus point schedu...        500.0
# 1     Receipt number 5 completed, bonus point schedu...        150.0
# 2                            All-receipts receipt bonus            5
# 3                            All-receipts receipt bonus          5.0
# ...

# %%
Receipt2 = pd.read_sql('Select * from FetchRewards.dbo.Receipt2', cnxn_str)
Receipt2
# Out:
#       _ParentKeyField       barcode  \
# 0                   1          4011
# 1                   2          4011
# 2                   2  028400642255
# 3                   3          None
# 4                   4          4011
# ...               ...           ...
# 6936             1114    B07BRRLSVC
# 6937             1115    B076FJ92M4
# 6938             1115    B07BRRLSVC
# 6939             1118    B076FJ92M4
# 6940             1118    B07BRRLSVC
#
#                                             description finalPrice itemPrice  \
# 0                                        ITEM NOT FOUND      26.00     26.00
# 1                                        ITEM NOT FOUND          1         1
# 2     DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00     10.00
# 3                                                  None       None      None
# 4                                        ITEM NOT FOUND      28.00     28.00
# ...

# %%
Brand = pd.read_sql('Select * from FetchRewards.dbo.Brand', cnxn_str)
Brand
# Out:
#                            _id       barcode            category  \
# 0     601ac115be37ce2ead437551  511111019862              Baking
# 1     601c5460be37ce2ead43755f  511111519928           Beverages
# 2     601ac142be37ce2ead43755d  511111819905              Baking
# 3     601ac142be37ce2ead43755a  511111519874              Baking
# 4     601ac142be37ce2ead43755e  511111319917      Candy & Sweets
# ...                        ...           ...                 ...
# 1162  5f77274dbe37ce6b592e90c0  511111116752              Baking
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328  Breakfast & Cereal
# 1164  5f494c6e04db711dd8fe87e7  511111416173      Candy & Sweets
# 1165  5a021611e4b00efe02b02a57  511111400608             Grocery
# 1166  6026d757be37ce6369301468  511111019930              Baking
#
#           categoryCode                       cpg  $ref  \
# 0               BAKING  601ac114be37ce2ead437550  Cogs
# 1            BEVERAGES  5332f5fbe4b03c9a25efd0ba  Cogs
# ...

# %%
Users = pd.read_sql('Select * from FetchRewards.dbo.[User]', cnxn_str)
Users
# Out:
#                            _id active      role signUpSource state  \
# 0     5ff1e194b6a9d73a3a9f1052   True  consumer        Email    WI
# 1     5ff1e194b6a9d73a3a9f1052   True  consumer        Email    WI
# 2     5ff1e194b6a9d73a3a9f1052   True  consumer        Email    WI
# 3     5ff1e1eacfcf6c399c274ae6   True  consumer        Email    WI
# 4     5ff1e194b6a9d73a3a9f1052   True  consumer        Email    WI
# ...                        ...    ...       ...          ...   ...
# 1975                      None   None      None         None  None
# 1976                      None   None      None         None  None
# 1977                      None   None      None         None  None
# 1978                      None   None      None         None  None
# 1979                      None   None      None         None  None
#
#                  createdDate               lastLogin
# 0    2021-01-03 00:00:18.630 2021-01-03 00:00:18.630
# 1    2021-01-03 00:00:18.630 2021-01-03 00:00:18.630
# ...

# %%
Receipt1.isnull().sum()
# Out:
# _id                          0
# bonusPointsEarned          575
# bonusPointsEarnedReason    575
# pointsEarned               510
# purchasedItemCount         484
# rewardsReceiptStatus         0
# totalSpent                 435
# userId                       0
# createdDate                  0
# dateScanned                  0
# finishedDate               551
# modifyDate                   0
# pointsAwardedDate          582
# purchaseDate               448
# pid                          0
# dtype: int64

# %%
Receipt2.isnull().sum()
# Out:
# _ParentKeyField              0
# barcode                   3851
# description                381
# finalPrice                 174
# itemPrice                  174
# needsFetchReview          6128
# partnerItemId                0
# preventTargetGapPoints    6583
# quantityPurchased          174
# userFlaggedBarcode        6604
# userFlaggedNewItem        6618
# userFlaggedPrice          6642
# userFlaggedQuantity       6642
# dtype: int64

# %%
Users.isnull().sum()
# Out:
# _id              990
# active           990
# role             990
# signUpSource    1086
# state           1102
# createdDate        0
# lastLogin       1114
# dtype: int64

# %%
Brand.isnull().sum()
# Out:
# _id               0
# barcode           0
# category        155
# categoryCode    650
# cpg               0
# $ref              0
# name              0
# topBrand        612
# dtype: int64

# %%
Users.duplicated().sum()
# Out:
# 1726

# %%
Users.shape
# Out:
# (1980, 7)

# %%
cnxn_str.commit()
